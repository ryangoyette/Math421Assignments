# %%
```{r}



##Loading in data set.
adult11=read.csv("C:\\Users\\student\\Documents\\Senior\\R\\adult.csv", header=FALSE)

##Changing variable names.
names(adult11)[1]="age"
names(adult11)[2]="workclass"
names(adult11)[3]="fnlwgt"
names(adult11)[4]="education"
names(adult11)[5]="educationnum"
names(adult11)[6]="maritalstatus"
names(adult11)[7]="occupation"
names(adult11)[8]="relationship"
names(adult11)[9]="race"
names(adult11)[10]="sex"
names(adult11)[11]="capitalgain"
names(adult11)[12]="capitalloss"
names(adult11)[13]="hoursperweek"
names(adult11)[14]="nativecountry"
names(adult11)[15]="target"
str(adult11)

#2)
##Checking categorical variables for missing data and replacing it by the mode.

levels(adult11$workclass)
which.max(table(adult11$workclass))
levels(adult11$workclass)=c("Private", "Federal-gov", "Local-gov", "Never-worked", "Private", "Self-emp-inc", "Self-emp-not-inc", "State-gov", "Without-pay")

levels(adult11$education)
levels(adult11$maritalstatus)

levels(adult11$occupation)
which.max(table(adult11$occupation))
levels(adult11$occupation)=c("Prof-specialty", "Adm-clerical", "Armed-Forces", "Craft-repair", "Exec-managerial", "Farming-fishing", "Handlers-cleaners", "Machine-op-inspct", "Other-service", "Priv-house-serv", "Prof-specialty", "Protective-serv", "Sales", "Tech-support", "Transport-moving")

levels(adult11$relationship)
levels(adult11$race)
levels(adult11$sex)

levels(adult11$nativecountry)
which.max(table(adult11$nativecountry))
levels(adult11$nativecountry)=c("United-States", "Cambodia", "Canada", "China", "Columbia", "Cuba", "Dominican-Republic", "Ecuador", "El-Salvador", "England", "France", "Germany", "Greece", "Guatemala", "Haiti", "Holand-Netherlands", "Honduras", "Hong", "Hungary", "India", "Iran", "Ireland", "Italy", "Jamaica", "Japan", "Laos", "Mexico", "Nicaragua", "Outlying-US(Guam-USVI-etc)", "Peru", "Philippines", "Poland", "Portugal", "Puerto-Rico", "Scotland", "South", "Taiwan", "Thailand", "Trinadad&Tobago", "United-States", "Vietnam", "Yugoslavia")

levels(adult11$target)
levels(adult11$target)=c("0","1")

#3)
##Checking nominal data and replacing it with median. 

library(caret)
preProcess_missingdata_model <- preProcess(adult11, method='medianImpute')
preProcess_missingdata_model
trainData <- predict(preProcess_missingdata_model, newdata = adult11)
str(trainData)
sum(is.na(trainData))

#4)
##Limiting the number of groups in any variable with more than 10.

##Making nativecountry only five groups.
levels(adult11$nativecountry)=c("North-America", "Asia", "North-America", "Asia", "South-America", "North-America", "North-America", "South-America", "South-America", "Europe", "Europe", "Europe", "Europe", "South-America", "North-America", "Europe", "South-America", "Asia", "Europe", "Asia", "Other", "Europe", "Europe", "Other", "Asia", "Asia", "North-America", "South-America", "North-America", "South-America", "Other", "Europe", "Europe", "North-America", "Europe", "Other", "Other", "Asia", "Other", "North-America", "Other", "Other")

##Making education only five groups.
levels(adult11$education)=c("High", "High", "High", "Elementary", "Middle", "Middle", "High", "College", "College", "College", "Post-College", "High", "Post-College", "Elementary", "Post-College", "College")

##Making occupation only five groups.
levels(adult11$occupation)=c("Other", "Management", "Military", "Other", "Management", "Other", "Other", "Service", "Other", "Service", "Service", "Service", "Retail", "Service", "Service")

#5)
## Encoding categorical variables
dummies_model <- dummyVars(target~ ., data=trainData)
trainData_mat <- predict(dummies_model, newdata = trainData)

#6)
##Center and scale.
preProcess_missingdata_model <- preProcess(adult11, method= c("center", "scale"))
preProcess_missingdata_model

#7)
##Partition and build tree and report.
library(rpart)
library(rattle)
splitIndex <- createDataPartition(adult11$target, p = .7, list = FALSE, times = 1)
set.seed(2018)
train <- adult11[ splitIndex,]
test <- adult11[-splitIndex,]
mytree <- rpart(target ~ ., data = train, method = "class")
pred <- predict(mytree,test, type = "class")
cm11.1=confusionMatrix(data = pred, reference = test$target, positive = "1")
print(cm11.1)
fancyRpartPlot(mytree)

##Accuracy=.8458
##Balanced Accuracy=.7336

#8)
##Build a random forest using ranger.
library(ranger)
modelass118 = ranger(target ~., data = train)
pred3  = predict(modelass118, data = test)$predictions
cm11.3=confusionMatrix(pred3, test$target, positive="1")
print(cm11.3)

##Accuracy=.8667
##Balanced Accuracy=.7836

#9)
##Redo #3) with value replaced by mean. Rebuild the model.
adult11=read.csv("C:\\Users\\student\\Documents\\Senior\\R\\adult.csv", header=FALSE)
names(adult11)[1]="age"
names(adult11)[2]="workclass"
names(adult11)[3]="fnlwgt"
names(adult11)[4]="education"
names(adult11)[5]="educationnum"
names(adult11)[6]="maritalstatus"
names(adult11)[7]="occupation"
names(adult11)[8]="relationship"
names(adult11)[9]="race"
names(adult11)[10]="sex"
names(adult11)[11]="capitalgain"
names(adult11)[12]="capitalloss"
names(adult11)[13]="hoursperweek"
names(adult11)[14]="nativecountry"
names(adult11)[15]="target"
str(adult11)
levels(adult11$workclass)
which.max(table(adult11$workclass))
levels(adult11$workclass)=c("Private", "Federal-gov", "Local-gov", "Never-worked", "Private", "Self-emp-inc", "Self-emp-not-inc", "State-gov", "Without-pay")
levels(adult11$education)
levels(adult11$maritalstatus)
levels(adult11$occupation)
which.max(table(adult11$occupation))
levels(adult11$occupation)=c("Prof-specialty", "Adm-clerical", "Armed-Forces", "Craft-repair", "Exec-managerial", "Farming-fishing", "Handlers-cleaners", "Machine-op-inspct", "Other-service", "Priv-house-serv", "Prof-specialty", "Protective-serv", "Sales", "Tech-support", "Transport-moving")
levels(adult11$relationship)
levels(adult11$race)
levels(adult11$sex)
levels(adult11$nativecountry)
which.max(table(adult11$nativecountry))
levels(adult11$nativecountry)=c("United-States", "Cambodia", "Canada", "China", "Columbia", "Cuba", "Dominican-Republic", "Ecuador", "El-Salvador", "England", "France", "Germany", "Greece", "Guatemala", "Haiti", "Holand-Netherlands", "Honduras", "Hong", "Hungary", "India", "Iran", "Ireland", "Italy", "Jamaica", "Japan", "Laos", "Mexico", "Nicaragua", "Outlying-US(Guam-USVI-etc)", "Peru", "Philippines", "Poland", "Portugal", "Puerto-Rico", "Scotland", "South", "Taiwan", "Thailand", "Trinadad&Tobago", "United-States", "Vietnam", "Yugoslavia")
levels(adult11$target)
levels(adult11$target)=c("0","1")


func119=function(x)
{
  for(i in 1:length(x))
  {
    if(is.na(x[i])==1) x[i]=mean(x,na.rm=TRUE)
    else x[i]=x[i]
  }
  return(x)
}

adult11$age<-func119(adult11$age)
adult11$fnlwgt<-func119(adult11$fnlwgt)
adult11$educationnum<-func119(adult11$educationnum)
adult11$capitalgain<-func119(adult11$capitalgain)
adult11$capitalloss<-func119(adult11$capitalloss)
adult11$hoursperweek<-func119(adult11$hoursperweek)

#This is the part #4) to be removed for final question.
levels(adult11$nativecountry)=c("North-America", "Asia", "North-America", "Asia", "South-America", "North-America", "North-America", "South-America", "South-America", "Europe", "Europe", "Europe", "Europe", "South-America", "North-America", "Europe", "South-America", "Asia", "Europe", "Asia", "Other", "Europe", "Europe", "Other", "Asia", "Asia", "North-America", "South-America", "North-America", "South-America", "Other", "Europe", "Europe", "North-America", "Europe", "Other", "Other", "Asia", "Other", "North-America", "Other", "Other")
levels(adult11$education)=c("High", "High", "High", "Elementary", "Middle", "Middle", "High", "College", "College", "College", "Post-College", "High", "Post-College", "Elementary", "Post-College", "College")
levels(adult11$occupation)=c("Other", "Management", "Military", "Other", "Management", "Other", "Other", "Service", "Other", "Service", "Service", "Service", "Retail", "Service", "Service")

dummies_model <- dummyVars(target~ ., data=adult11)
trainData_mat <- predict(dummies_model, newdata = adult11)
preProcess_missingdata_model <- preProcess(adult11, method= c("center", "scale"))
preProcess_missingdata_model
splitIndex <- createDataPartition(adult11$target, p = .7, list = FALSE, times = 1)
set.seed(2018)
train <- adult11[ splitIndex,]
test <- adult11[-splitIndex,]
mytree <- rpart(target ~ ., data = train, method = "class")
pred <- predict(mytree,test, type = "class")
cm11.4=confusionMatrix(data = pred, reference = test$target, positive = "1")
print(cm11.4)
fancyRpartPlot(mytree)

##Accuracy=.8466
##Balanced Accuracy=.7432

#10)
##Redo #3) with missing values being replaced with the knn impute method.
adult11=read.csv("C:\\Users\\student\\Documents\\Senior\\R\\adult.csv", header=FALSE)
names(adult11)[1]="age"
names(adult11)[2]="workclass"
names(adult11)[3]="fnlwgt"
names(adult11)[4]="education"
names(adult11)[5]="educationnum"
names(adult11)[6]="maritalstatus"
names(adult11)[7]="occupation"
names(adult11)[8]="relationship"
names(adult11)[9]="race"
names(adult11)[10]="sex"
names(adult11)[11]="capitalgain"
names(adult11)[12]="capitalloss"
names(adult11)[13]="hoursperweek"
names(adult11)[14]="nativecountry"
names(adult11)[15]="target"
str(adult11)
levels(adult11$workclass)
which.max(table(adult11$workclass))
levels(adult11$workclass)=c("Private", "Federal-gov", "Local-gov", "Never-worked", "Private", "Self-emp-inc", "Self-emp-not-inc", "State-gov", "Without-pay")
levels(adult11$education)
levels(adult11$maritalstatus)
levels(adult11$occupation)
which.max(table(adult11$occupation))
levels(adult11$occupation)=c("Prof-specialty", "Adm-clerical", "Armed-Forces", "Craft-repair", "Exec-managerial", "Farming-fishing", "Handlers-cleaners", "Machine-op-inspct", "Other-service", "Priv-house-serv", "Prof-specialty", "Protective-serv", "Sales", "Tech-support", "Transport-moving")
levels(adult11$relationship)
levels(adult11$race)
levels(adult11$sex)
levels(adult11$nativecountry)
which.max(table(adult11$nativecountry))
levels(adult11$nativecountry)=c("United-States", "Cambodia", "Canada", "China", "Columbia", "Cuba", "Dominican-Republic", "Ecuador", "El-Salvador", "England", "France", "Germany", "Greece", "Guatemala", "Haiti", "Holand-Netherlands", "Honduras", "Hong", "Hungary", "India", "Iran", "Ireland", "Italy", "Jamaica", "Japan", "Laos", "Mexico", "Nicaragua", "Outlying-US(Guam-USVI-etc)", "Peru", "Philippines", "Poland", "Portugal", "Puerto-Rico", "Scotland", "South", "Taiwan", "Thailand", "Trinadad&Tobago", "United-States", "Vietnam", "Yugoslavia")
levels(adult11$target)
levels(adult11$target)=c("0","1")

preProcess_missingdata_model <- preProcess(adult11, method='knnImpute')
preProcess_missingdata_model
trainData <- predict(preProcess_missingdata_model, newdata = adult11)
str(trainData)
sum(is.na(trainData))

#This is the part #4) to be removed for final question.
levels(adult11$nativecountry)=c("North-America", "Asia", "North-America", "Asia", "South-America", "North-America", "North-America", "South-America", "South-America", "Europe", "Europe", "Europe", "Europe", "South-America", "North-America", "Europe", "South-America", "Asia", "Europe", "Asia", "Other", "Europe", "Europe", "Other", "Asia", "Asia", "North-America", "South-America", "North-America", "South-America", "Other", "Europe", "Europe", "North-America", "Europe", "Other", "Other", "Asia", "Other", "North-America", "Other", "Other")
levels(adult11$education)=c("High", "High", "High", "Elementary", "Middle", "Middle", "High", "College", "College", "College", "Post-College", "High", "Post-College", "Elementary", "Post-College", "College")
levels(adult11$occupation)=c("Other", "Management", "Military", "Other", "Management", "Other", "Other", "Service", "Other", "Service", "Service", "Service", "Retail", "Service", "Service")

dummies_model <- dummyVars(target~ ., data=trainData)
trainData_mat <- predict(dummies_model, newdata = trainData)
preProcess_missingdata_model <- preProcess(adult11, method= c("center", "scale"))
preProcess_missingdata_model

splitIndex <- createDataPartition(adult11$target, p = .7, list = FALSE, times = 1)
set.seed(2018)
train <- adult11[ splitIndex,]
test <- adult11[-splitIndex,]
mytree <- rpart(target ~ ., data = train, method = "class")
pred <- predict(mytree,test, type = "class")
cm11.5=confusionMatrix(data = pred, reference = test$target, positive = "1")
print(cm11.5)
fancyRpartPlot(mytree)

##Accuracy=.8424
##Balanced Accuracy=.7308

#10)
##Redo #6) with scaling and centering only the non-encoded variables, meaning only nominal.
##1-5 code
adult11=read.csv("C:\\Users\\student\\Documents\\Senior\\R\\adult.csv", header=FALSE)
names(adult11)[1]="age"
names(adult11)[2]="workclass"
names(adult11)[3]="fnlwgt"
names(adult11)[4]="education"
names(adult11)[5]="educationnum"
names(adult11)[6]="maritalstatus"
names(adult11)[7]="occupation"
names(adult11)[8]="relationship"
names(adult11)[9]="race"
names(adult11)[10]="sex"
names(adult11)[11]="capitalgain"
names(adult11)[12]="capitalloss"
names(adult11)[13]="hoursperweek"
names(adult11)[14]="nativecountry"
names(adult11)[15]="target"
str(adult11)
levels(adult11$workclass)
which.max(table(adult11$workclass))
levels(adult11$workclass)=c("Private", "Federal-gov", "Local-gov", "Never-worked", "Private", "Self-emp-inc", "Self-emp-not-inc", "State-gov", "Without-pay")
levels(adult11$education)
levels(adult11$maritalstatus)
levels(adult11$occupation)
which.max(table(adult11$occupation))
levels(adult11$occupation)=c("Prof-specialty", "Adm-clerical", "Armed-Forces", "Craft-repair", "Exec-managerial", "Farming-fishing", "Handlers-cleaners", "Machine-op-inspct", "Other-service", "Priv-house-serv", "Prof-specialty", "Protective-serv", "Sales", "Tech-support", "Transport-moving")
levels(adult11$relationship)
levels(adult11$race)
levels(adult11$sex)
levels(adult11$nativecountry)
which.max(table(adult11$nativecountry))
levels(adult11$nativecountry)=c("United-States", "Cambodia", "Canada", "China", "Columbia", "Cuba", "Dominican-Republic", "Ecuador", "El-Salvador", "England", "France", "Germany", "Greece", "Guatemala", "Haiti", "Holand-Netherlands", "Honduras", "Hong", "Hungary", "India", "Iran", "Ireland", "Italy", "Jamaica", "Japan", "Laos", "Mexico", "Nicaragua", "Outlying-US(Guam-USVI-etc)", "Peru", "Philippines", "Poland", "Portugal", "Puerto-Rico", "Scotland", "South", "Taiwan", "Thailand", "Trinadad&Tobago", "United-States", "Vietnam", "Yugoslavia")
levels(adult11$target)
levels(adult11$target)=c("0","1")
library(caret)
preProcess_missingdata_model <- preProcess(adult11, method='medianImpute')
preProcess_missingdata_model
trainData <- predict(preProcess_missingdata_model, newdata = adult11)
str(trainData)
sum(is.na(trainData))
levels(adult11$nativecountry)=c("North-America", "Asia", "North-America", "Asia", "South-America", "North-America", "North-America", "South-America", "South-America", "Europe", "Europe", "Europe", "Europe", "South-America", "North-America", "Europe", "South-America", "Asia", "Europe", "Asia", "Other", "Europe", "Europe", "Other", "Asia", "Asia", "North-America", "South-America", "North-America", "South-America", "Other", "Europe", "Europe", "North-America", "Europe", "Other", "Other", "Asia", "Other", "North-America", "Other", "Other")
levels(adult11$education)=c("High", "High", "High", "Elementary", "Middle", "Middle", "High", "College", "College", "College", "Post-College", "High", "Post-College", "Elementary", "Post-College", "College")
levels(adult11$occupation)=c("Other", "Management", "Military", "Other", "Management", "Other", "Other", "Service", "Other", "Service", "Service", "Service", "Retail", "Service", "Service")

preProcess_missingdata_model <- preProcess(adult11, method= c("center", "scale"))
preProcess_missingdata_model
dummies_model <- dummyVars(target~ ., data=trainData)
trainData_mat <- predict(dummies_model, newdata = trainData)

splitIndex <- createDataPartition(adult11$target, p = .7, list = FALSE, times = 1)
set.seed(2018)
train <- adult11[ splitIndex,]
test <- adult11[-splitIndex,]
mytree <- rpart(target ~ ., data = train, method = "class")
pred <- predict(mytree,test, type = "class")
cm11.6=confusionMatrix(data = pred, reference = test$target, positive = "1")
print(cm11.6)
fancyRpartPlot(mytree)

##Accuracy=.8424
##Balanced Accuracy=.7308

#12) 
##Redo #5) with a different encoding method.
adult11=read.csv("C:\\Users\\student\\Documents\\Senior\\R\\adult.csv", header=FALSE)
names(adult11)[1]="age"
names(adult11)[2]="workclass"
names(adult11)[3]="fnlwgt"
names(adult11)[4]="education"
names(adult11)[5]="educationnum"
names(adult11)[6]="maritalstatus"
names(adult11)[7]="occupation"
names(adult11)[8]="relationship"
names(adult11)[9]="race"
names(adult11)[10]="sex"
names(adult11)[11]="capitalgain"
names(adult11)[12]="capitalloss"
names(adult11)[13]="hoursperweek"
names(adult11)[14]="nativecountry"
names(adult11)[15]="target"
str(adult11)
levels(adult11$workclass)
which.max(table(adult11$workclass))
levels(adult11$workclass)=c("Private", "Federal-gov", "Local-gov", "Never-worked", "Private", "Self-emp-inc", "Self-emp-not-inc", "State-gov", "Without-pay")
levels(adult11$education)
levels(adult11$maritalstatus)
levels(adult11$occupation)
which.max(table(adult11$occupation))
levels(adult11$occupation)=c("Prof-specialty", "Adm-clerical", "Armed-Forces", "Craft-repair", "Exec-managerial", "Farming-fishing", "Handlers-cleaners", "Machine-op-inspct", "Other-service", "Priv-house-serv", "Prof-specialty", "Protective-serv", "Sales", "Tech-support", "Transport-moving")
levels(adult11$relationship)
levels(adult11$race)
levels(adult11$sex)
levels(adult11$nativecountry)
which.max(table(adult11$nativecountry))
levels(adult11$nativecountry)=c("United-States", "Cambodia", "Canada", "China", "Columbia", "Cuba", "Dominican-Republic", "Ecuador", "El-Salvador", "England", "France", "Germany", "Greece", "Guatemala", "Haiti", "Holand-Netherlands", "Honduras", "Hong", "Hungary", "India", "Iran", "Ireland", "Italy", "Jamaica", "Japan", "Laos", "Mexico", "Nicaragua", "Outlying-US(Guam-USVI-etc)", "Peru", "Philippines", "Poland", "Portugal", "Puerto-Rico", "Scotland", "South", "Taiwan", "Thailand", "Trinadad&Tobago", "United-States", "Vietnam", "Yugoslavia")
levels(adult11$target)
levels(adult11$target)=c("0","1")
library(caret)
preProcess_missingdata_model <- preProcess(adult11, method='medianImpute')
preProcess_missingdata_model
trainData <- predict(preProcess_missingdata_model, newdata = adult11)
str(trainData)
sum(is.na(trainData))
levels(adult11$nativecountry)=c("North-America", "Asia", "North-America", "Asia", "South-America", "North-America", "North-America", "South-America", "South-America", "Europe", "Europe", "Europe", "Europe", "South-America", "North-America", "Europe", "South-America", "Asia", "Europe", "Asia", "Other", "Europe", "Europe", "Other", "Asia", "Asia", "North-America", "South-America", "North-America", "South-America", "Other", "Europe", "Europe", "North-America", "Europe", "Other", "Other", "Asia", "Other", "North-America", "Other", "Other")
levels(adult11$education)=c("High", "High", "High", "Elementary", "Middle", "Middle", "High", "College", "College", "College", "Post-College", "High", "Post-College", "Elementary", "Post-College", "College")
levels(adult11$occupation)=c("Other", "Management", "Military", "Other", "Management", "Other", "Other", "Service", "Other", "Service", "Service", "Service", "Retail", "Service", "Service")
##Encoded by squaring every value for the categorical variables.
adult11$workclass=as.numeric(adult11$workclass)^2
adult11$education=as.numeric(adult11$education)^2
adult11$maritalstatus=as.numeric(adult11$maritalstatus)^2
adult11$occupation=as.numeric(adult11$occupation)^2
adult11$relationship=as.numeric(adult11$relationship)^2
adult11$race=as.numeric(adult11$race)^2
adult11$sex=as.numeric(adult11$sex)^2
adult11$nativecountry=as.numeric(adult11$nativecountry)^2
##This is after the encoding.
preProcess_missingdata_model <- preProcess(adult11, method= c("center", "scale"))
preProcess_missingdata_model
splitIndex <- createDataPartition(adult11$target, p = .7, list = FALSE, times = 1)
set.seed(2018)
train <- adult11[ splitIndex,]
test <- adult11[-splitIndex,]
mytree <- rpart(target ~ ., data = train, method = "class")
pred <- predict(mytree,test, type = "class")
cm11.7=confusionMatrix(data = pred, reference = test$target, positive = "1")
print(cm11.7)
fancyRpartPlot(mytree)

##Accuracy=.8417
##Balanced Accuracy=.7327

#13)
##Rebuilding the first two models without #4).
##First Model
adult11=read.csv("C:\\Users\\student\\Documents\\Senior\\R\\adult.csv", header=FALSE)
names(adult11)[1]="age"
names(adult11)[2]="workclass"
names(adult11)[3]="fnlwgt"
names(adult11)[4]="education"
names(adult11)[5]="educationnum"
names(adult11)[6]="maritalstatus"
names(adult11)[7]="occupation"
names(adult11)[8]="relationship"
names(adult11)[9]="race"
names(adult11)[10]="sex"
names(adult11)[11]="capitalgain"
names(adult11)[12]="capitalloss"
names(adult11)[13]="hoursperweek"
names(adult11)[14]="nativecountry"
names(adult11)[15]="target"
str(adult11)
levels(adult11$workclass)
which.max(table(adult11$workclass))
levels(adult11$workclass)=c("Private", "Federal-gov", "Local-gov", "Never-worked", "Private", "Self-emp-inc", "Self-emp-not-inc", "State-gov", "Without-pay")
levels(adult11$education)
levels(adult11$maritalstatus)
levels(adult11$occupation)
which.max(table(adult11$occupation))
levels(adult11$occupation)=c("Prof-specialty", "Adm-clerical", "Armed-Forces", "Craft-repair", "Exec-managerial", "Farming-fishing", "Handlers-cleaners", "Machine-op-inspct", "Other-service", "Priv-house-serv", "Prof-specialty", "Protective-serv", "Sales", "Tech-support", "Transport-moving")
levels(adult11$relationship)
levels(adult11$race)
levels(adult11$sex)
levels(adult11$nativecountry)
which.max(table(adult11$nativecountry))
levels(adult11$nativecountry)=c("United-States", "Cambodia", "Canada", "China", "Columbia", "Cuba", "Dominican-Republic", "Ecuador", "El-Salvador", "England", "France", "Germany", "Greece", "Guatemala", "Haiti", "Holand-Netherlands", "Honduras", "Hong", "Hungary", "India", "Iran", "Ireland", "Italy", "Jamaica", "Japan", "Laos", "Mexico", "Nicaragua", "Outlying-US(Guam-USVI-etc)", "Peru", "Philippines", "Poland", "Portugal", "Puerto-Rico", "Scotland", "South", "Taiwan", "Thailand", "Trinadad&Tobago", "United-States", "Vietnam", "Yugoslavia")
levels(adult11$target)
levels(adult11$target)=c("0","1")
library(caret)
preProcess_missingdata_model <- preProcess(adult11, method='medianImpute')
preProcess_missingdata_model
trainData <- predict(preProcess_missingdata_model, newdata = adult11)
str(trainData)
sum(is.na(trainData))
dummies_model <- dummyVars(target~ ., data=trainData)
trainData_mat <- predict(dummies_model, newdata = trainData)
preProcess_missingdata_model <- preProcess(adult11, method= c("center", "scale"))
preProcess_missingdata_model
library(rpart)
library(rattle)
splitIndex <- createDataPartition(adult11$target, p = .7, list = FALSE, times = 1)
set.seed(2018)
train <- adult11[ splitIndex,]
test <- adult11[-splitIndex,]
mytree <- rpart(target ~ ., data = train, method = "class")
pred <- predict(mytree,test, type = "class")
cm11.8=confusionMatrix(data = pred, reference = test$target, positive = "1")
print(cm11.8)
fancyRpartPlot(mytree)

##Accuracy=.8424
##Balanced Accuracy=.7308

##Build a random forest using ranger.
modelass119 = ranger(target ~., data = train)
pred4  = predict(modelass119, data = test)$predictions
cm11.9=confusionMatrix(pred4, test$target, positive="1")
print(cm11.9)

##Accuracy=.8623
##Balanced Accuracy=.7807

##Skipping step #4) did not help. 
```
