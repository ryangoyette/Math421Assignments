# %%
#1)

```{r}
func1=function(x)
{
  return(x^2+3*x+1)
}
func1(3)
3^2+3*3+1
```

#2)

```{r}
func2=function(x)
{
  s=1
  for(i in 1:length(x))
  {
    s=s*x[i]
  }
  return(s)
}
e=c(1,2,3,4,5)
func2(e)
```


#3)

```{r}
func3=function(x,n)
{
  for(i in 1:length(x))
  {
    if(is.na(x[i])==1) x[i]=n
    else x[i]=x[i]
  }
  return(x)
}
f=c(1,2,3,NA,5,6,NA)
func3(f,100)
```

#4)

```{r}
func4=function(x)
{
  for(i in 1:length(x))
  {
    if(is.na(x[i])==1) x[i]=mean(x,na.rm=TRUE)
    else x[i]=x[i]
  }
  return(x)
}
g=c(1,2,3,NA,4,5,NA)
func4(g)
```

#5)

```{r}
titanic=read.csv("titanic.csv")
func5=function(x)
{
  for(j in 1:ncol(x))
  {
    for(i in 1:length(x[,j]))
    {
      if(is.na(x[i,j])==1) x[i,j]=mean(x[,j],na.rm=TRUE)
      else x[i,j]=x[i,j]
    }
  }
  return(x)
}
```



#6)

```{r}
library(ggplot2)
func6=function(a,b)
{
  return(ggplot(a, aes(x=a[,b]))+geom_bar())
}
func6(titanic, 3)
```

#7)

## The code for this function works in R, it is only when it is knit that it does not work.

```{r}
func7=function(a,b,c)
{
  return(ggplot(a, aes(x=a[,b],fill=a[,c]))+geom_bar())
}
func7(titanic, 3,2)
```
